# %%
import os
import glob
import numpy as np
import nibabel as nib
from pathlib import Path

# %%
#Define the path to your dataset
TRAIN_DATASET_PATH = '../../../../raw_data/segmentation/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData'
#Load sample images and visualize
image_t1c = nib.load(TRAIN_DATASET_PATH + '/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1c.nii.gz').get_fdata()
image_t1n = nib.load(TRAIN_DATASET_PATH + '/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t1n.nii.gz').get_fdata()
image_t2f = nib.load(TRAIN_DATASET_PATH + '/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2f.nii.gz').get_fdata()
image_t2w = nib.load(TRAIN_DATASET_PATH + '/BraTS-GLI-00000-000/BraTS-GLI-00000-000-t2w.nii.gz').get_fdata()
