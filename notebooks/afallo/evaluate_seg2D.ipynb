# %%
from brain.interface.main import evaluate_seg2D
from brain.registry import load_model_docker
from brain.ml_logic_segmentation_2D.data import load_path_seg_df
from sklearn.model_selection import train_test_split
from brain.ml_logic_segmentation_2D.preprocess import ColorContrastDataGenerator

# %%
model = load_model_docker("../../brain/models/seg2D.h5")
# Out:
# 2026-01-26 14:48:55.089362: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded from local disk

# %%
df = load_path_seg_df('/home/aurore/code/afallo/brain_tumor_detection_project/raw_data/segmentation/kaggle_3m/')


train_val_df, test_df = train_test_split(df, test_size=0.15, random_state=42)
# Out:
# 🕵️‍♂️ Analyse et vérification des fichiers en cours...
# Original -> Tumeurs: 1373 | Sains: 2556

# %%
test_df = train_val_df[train_val_df["image_path"] == "/home/aurore/code/afallo/brain_tumor_detection_project/raw_data/segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_15.tif"]

# %%
test_df
# Out:
#                                             image_path  \
# 162  /home/aurore/code/afallo/brain_tumor_detection...
#
#                                              mask_path  has_tumor
# 162  /home/aurore/code/afallo/brain_tumor_detection...          1

# %%
test_gen_color = ColorContrastDataGenerator(test_df, batch_size=1, img_size=256, shuffle=False)

# %%
evaluate_seg2D(model, test_gen_color)
# Out:
# /home/aurore/.pyenv/versions/brain_test-env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step - accuracy: 0.9879 - dice_coef: 0.8121 - loss: 0.1879
# [0.18785977363586426, 0.9879302978515625, 0.8121402263641357]
