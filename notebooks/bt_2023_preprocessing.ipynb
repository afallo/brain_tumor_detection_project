# %%
import os
import glob
import numpy as np
import nibabel as nib
from pathlib import Path

# %%
RAW_ROOT = Path("../raw_data/segmentation/brats2023_raw")
OUT_ROOT = Path("../raw_data/segmentation/brats2023_preprocessed")


# Taille cible
TARGET_SHAPE = (160, 192, 160)  # (H, W, D)

# On choisit un ordre de canaux cohérent (à garder ensuite dans le Model)
# [T1 = t1 native, T1c, T2w, T2 FLAIR]
MODALITIES = [
    ("t1n", "*-t1n.nii.gz"),
    ("t1c", "*-t1c.nii.gz"),
    ("t2w", "*-t2w.nii.gz"),
    ("t2f", "*-t2f.nii.gz"),
]

# %%
## Normalize the images per modality
"""vol: np.ndarray (H, W, D), intensités brutes"""
def normalize_volume(vol):
    mask = vol > 0
    if np.any(mask):
        mean = vol[mask].mean()
        std = vol[mask].std()
        vol[mask] = (vol[mask] - mean) / (std + 1e-8)
    return vol

# %%
## Crop/pad au centre pour atteindre TARGET_SHAPE
def crop_or_pad(vol, target_shape):
    H, W, D = vol.shape
    Ht, Wt, Dt = target_shape
    out = np.zeros(target_shape, dtype=vol.dtype)

    h_start = max((Ht - H) // 2, 0)
    w_start = max((Wt - W) // 2, 0)
    d_start = max((Dt - D) // 2, 0)

    h_end = h_start + min(H, Ht)
    w_end = w_start + min(W, Wt)
    d_end = d_start + min(D, Dt)

    vh_start = max((H - Ht) // 2, 0)
    vw_start = max((W - Wt) // 2, 0)
    vd_start = max((D - Dt) // 2, 0)

    vh_end = vh_start + (h_end - h_start)
    vw_end = vw_start + (w_end - w_start)
    vd_end = vd_start + (d_end - d_start)

    out[h_start:h_end, w_start:w_end, d_start:d_end] = vol[vh_start:vh_end,
                                                            vw_start:vw_end,
                                                            vd_start:vd_end]
    return out

# %%
def process_case(case_dir: Path):
    vols = []

    # Charger les 4 modalités dans l’ordre défini dans MODALITIES
    for mod_name, pattern in MODALITIES:
        fpath_list = list(case_dir.glob(pattern))
        assert len(fpath_list) == 1, f"Problème pour {mod_name} dans {case_dir}"
        fpath = fpath_list[0]

        nii = nib.load(str(fpath))
        vol = nii.get_fdata().astype(np.float32)
        vol = normalize_volume(vol)
        vol = crop_or_pad(vol, TARGET_SHAPE)
        vols.append(vol)

    # (H,W,D,4)
    img = np.stack(vols, axis=-1).astype(np.float32)

    # Charger le label
    seg_path_list = list(case_dir.glob("*-seg.nii.gz"))
    assert len(seg_path_list) == 1, f"Pas de seg ou multiple seg dans {case_dir}"
    seg_path = seg_path_list[0]

    seg = nib.load(str(seg_path)).get_fdata()
    seg = crop_or_pad(seg, TARGET_SHAPE)
    seg = seg.astype(np.uint8)   # labels {0,1,2,4}
    seg[seg == 4] = 3

    return img, seg

# %%
case_dirs = sorted([p for p in RAW_ROOT.iterdir() if p.is_dir()])

# %%
OUT_ROOT.mkdir(parents=True, exist_ok=True)
for case_dir in case_dirs:
    case_id = case_dir.name  # ex: BraTS-GLI-00000-000
    out_path = OUT_ROOT / f"{case_id}.npz"

    img, seg = process_case(case_dir)
    np.savez_compressed(out_path, image=img, label=seg)
    print("Saved", out_path)
# Out:
# Saved ../raw_data/segmentation/brats2023_preprocessed/BraTS-GLI-00000-000.npz
# Saved ../raw_data/segmentation/brats2023_preprocessed/BraTS-GLI-00002-000.npz
# Saved ../raw_data/segmentation/brats2023_preprocessed/BraTS-GLI-00003-000.npz
# Saved ../raw_data/segmentation/brats2023_preprocessed/BraTS-GLI-00005-000.npz
# Saved ../raw_data/segmentation/brats2023_preprocessed/BraTS-GLI-00006-000.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       2 case_id = case_dir.name  # ex: BraTS-GLI-00000-000
#       3 out_path = OUT_ROOT / f"{case_id}.npz"
# ----> 5 img, seg = process_case(case_dir)
#       6 np.savez_compressed(out_path, image=img, label=seg)
#       7 print("Saved", out_path)
#
# Cell In[6], line 11, in process_case(case_dir)
#       8 fpath = fpath_list[0]
#      10 nii = nib.load(str(fpath))
# ---> 11 vol = nii.get_fdata().astype(np.float32)
#      12 vol = normalize_volume(vol)
#      13 vol = crop_or_pad(vol, TARGET_SHAPE)
#
# File ~/.pyenv/versions/brain2-env/lib/python3.10/site-packages/nibabel/dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File ~/.pyenv/versions/brain2-env/lib/python3.10/site-packages/nibabel/arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File ~/.pyenv/versions/brain2-env/lib/python3.10/site-packages/nibabel/arrayproxy.py:421, in ArrayProxy._get_scaled(self, dtype, slicer)
#     419     scl_inter = scl_inter.astype(use_dtype)
#     420 # Read array and upcast as necessary for big slopes, intercepts
# --> 421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
#     423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~/.pyenv/versions/brain2-env/lib/python3.10/site-packages/nibabel/arrayproxy.py:391, in ArrayProxy._get_unscaled(self, slicer)
#     387 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     388     (), self._shape, False
#     389 ):
#     390     with self._get_fileobj() as fileobj, self._lock:
# --> 391         return array_from_file(
#     392             self._shape,
#     393             self._dtype,
#     394             fileobj,
#     395             offset=self._offset,
#     396             order=self.order,
#     397             mmap=self._mmap,
#     398         )
#     399 with self._get_fileobj() as fileobj:
#     400     return fileslice(
#     401         fileobj,
#     402         slicer,
#    (...)
#     407         lock=self._lock,
#     408     )
#
# File ~/.pyenv/versions/brain2-env/lib/python3.10/site-packages/nibabel/volumeutils.py:467, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     465 if hasattr(infile, 'readinto'):
#     466     data_bytes = bytearray(n_bytes)
# --> 467     n_read = infile.readinto(data_bytes)
#     468     needs_copy = False
#     469 else:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/_compression.py:67, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
# ---> 67     with memoryview(b) as view, view.cast("B") as byte_view:
#      68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#
# KeyboardInterrupt:
