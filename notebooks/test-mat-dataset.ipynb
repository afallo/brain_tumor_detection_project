# %% [markdown]
# #### TEST TO OPEN .MAT FILES

# %%
from pathlib import Path
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
mat_path = Path("/Users/abirbou/code/afallo/brain_tumor_detection_project/notebooks/443.mat")

print(mat_path)
print(mat_path.exists())  # doit afficher True

with h5py.File(mat_path, "r") as f:
    grp = f["cjdata"]
    print(list(grp.keys()))   # par ex. ['image', 'label', 'PID']
    img = grp["image"][:]
    label = grp["label"][:]
    pid = grp["PID"][:]
    tumor_border = grp["tumorBorder"][:]
    tumor_mask = grp["tumorMask"][:]


print(img.shape)
print(label[0])
print(pid)

plt.imshow(img, cmap="gray")
# Out:
# /Users/abirbou/code/afallo/brain_tumor_detection_project/notebooks/443.mat
# True
# ['PID', 'image', 'label', 'tumorBorder', 'tumorMask']
# (512, 512)
# [1.]
# [[49]
#  [48]
#  [48]
#  [51]
#  [54]
#  [48]]

# %%
plt.imshow(tumor_mask, cmap="gray")

# %%
plt.imshow(tumor_border, cmap="gray")
